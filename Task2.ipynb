# %% [markdown]
# <a href="https://colab.research.google.com/github/Spo-od/DataAn/blob/main/Task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **Traffic Data Cleaning Task**

# %% [markdown]
# 1.Data Exploration:Load the dataset and display:
#
# First 5 rows (head()).
#
# Dataset information (info()).
#
# Basic statistical summary (describe()).

# %%
import warnings
warnings.filterwarnings('ignore')

#importing the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



traffic = pd.read_csv('/content/traffic.csv')

traffic.head(5)
traffic.describe()
traffic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2976 entries, 0 to 2975
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Time               2976 non-null   object
#  1   Date               2976 non-null   int64
#  2   Day of the week    2976 non-null   object
#  3   CarCount           2976 non-null   int64
#  4   BikeCount          2976 non-null   int64
#  5   BusCount           2976 non-null   int64
#  6   TruckCount         2976 non-null   int64
#  7   Total              2976 non-null   int64
#  8   Traffic Situation  2976 non-null   object
# dtypes: int64(6), object(3)
# memory usage: 209.4+ KB

# %% [markdown]
# 2.Missing Values Handling:
# Check for missing values in the dataset.
#
# If any missing values are found:
#
# For CarCount, BikeCount, BusCount, TruckCount: replace missing values with their respective column means.
#
# For Traffic Situation: replace missing values with the most frequent category (mode).
#
# For Day of the week: drop any rows containing missing values.

# %%
traffic.isnull().sum()

for col in ['CarCount', 'BikeCount', 'BusCount', 'TruckCount']:
    if col in traffic.columns:
        mean_value = traffic[col].mean()
        traffic[col].fillna(mean_value, inplace=True)

if 'Traffic Situation' in traffic.columns:
    mode_value = traffic['Traffic Situation'].mode()[0]
    traffic['Traffic Situation'].fillna(mode_value, inplace=True)

if 'Day of the week' in traffic.columns:
    traffic.dropna(subset=['Day of the week'], inplace=True)

print("\nMissing values after handling:\n", traffic.isnull().sum())
# Out:
# Missing values after handling:
#  Time                 0
# Date                 0
# Day of the week      0
# CarCount             0
# BikeCount            0
# BusCount             0
# TruckCount           0
# Total                0
# Traffic Situation    0
# dtype: int64

# %% [markdown]
# 3.Duplicate Records:
# Check for duplicate rows.
#
# If duplicates are found, remove them.

# %%
duplicate_count = traffic.duplicated().sum()
print(f"Number of duplicate rows: {duplicate_count}")

traffic.drop_duplicates(inplace=True)
# Out:
# Number of duplicate rows: 0

# %% [markdown]
# 4.Outliers Detection and Treatment :
# For columns: CarCount, BikeCount, BusCount, TruckCount, Total
#
# Detect if any value is:
#
# Less than 0 (which is impossible for counts).
#
# Extremely high (using IQR method or quantile method).
#
# If an outlier is found:
#
# Replace it with the median of that column.

# %%
for col in ['CarCount', 'BikeCount', 'BusCount', 'TruckCount']:
    if col in traffic.columns:
        Q1 = traffic[col].quantile(0.25)
        Q3 = traffic[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        median = traffic[col].median()

        traffic[col] = traffic[col].apply(lambda x: median if (x < 0 or x > upper_bound) else x)

# %% [markdown]
# 5.Vehicle Distribution Analysis:
# Plot the distribution of CarCount, BikeCount, BusCount, and TruckCount:
#
# Use Boxplots and Histograms for visualization.
#
# Comment on which vehicle type shows the highest variability.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# List of columns to plot
columns = ['CarCount', 'BikeCount', 'BusCount', 'TruckCount']

# Set general style
sns.set(style="whitegrid")

# Plot Boxplots
plt.figure(figsize=(12, 6))
for i, col in enumerate(columns):
    plt.subplot(1, 4, i+1)
    sns.boxplot(y=traffic[col])
    plt.title(col)
plt.tight_layout()
plt.show()

# Plot Histograms
plt.figure(figsize=(12, 8))
for i, col in enumerate(columns):
    plt.subplot(2, 2, i+1)
    sns.histplot(traffic[col], bins=20, kde=True)
    plt.title(col)
plt.tight_layout()
plt.show()

# %% [markdown]
# 6.Traffic Situation Distribution:
# Visualize the counts of each Traffic Situation category (low, normal, high):
#
# Use either a Bar Chart or Pie Chart.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Bar Chart
plt.figure(figsize=(8, 5))
sns.countplot(x='Traffic Situation', data=traffic, order=traffic['Traffic Situation'].value_counts().index)
plt.title("Traffic Situation Distribution (Bar Chart)")
plt.xlabel("Traffic Situation")
plt.ylabel("Count")
plt.show()

# Pie Chart
plt.figure(figsize=(6, 6))
traffic['Traffic Situation'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, colors=sns.color_palette("Set2"))
plt.title("Traffic Situation Distribution (Pie Chart)")
plt.ylabel("")
plt.show()

# %% [markdown]
# 7.Save Cleaned Data:
# Save the cleaned dataset to a new CSV file named:
# traffic_cleaned.csv

# %%
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-22-3569823280> in <cell line: 0>()
# ----> 1 traffic.to_csv('/mnt/data/traffic.csv', index=False)
#
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     331                     stacklevel=find_stack_level(),
#     332                 )
# --> 333             return func(*args, **kwargs)
#     334
#     335         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3965         )
#    3966
# -> 3967         return DataFrameRenderer(formatter).to_csv(
#    3968             path_or_buf,
#    3969             lineterminator=lineterminator,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1012             formatter=self.fmt,
#    1013         )
# -> 1014         csv_formatter.save()
#    1015
#    1016         if created_buffer:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/csvs.py in save(self)
#     249         """
#     250         # apply compression and byte/text conversion
# --> 251         with get_handle(
#     252             self.filepath_or_buffer,
#     253             self.mode,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     747     # Only for write methods
#     748     if "r" not in mode and is_path:
# --> 749         check_parent_directory(str(handle))
#     750
#     751     if compression:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/common.py in check_parent_directory(path)
#     614     parent = Path(path).parent
#     615     if not parent.is_dir():
# --> 616         raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#     617
#     618
#
# OSError: Cannot save file into a non-existent directory: '/mnt/data'
